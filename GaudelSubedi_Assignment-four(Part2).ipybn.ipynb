# %% [markdown]
# # question 1.4(a)

# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json

Consumer_Key = 'oQ4wA3nWX6SrXaK5HdmQBOdw8'
Consumer_Secret = 'XH2usYlx0Kp3gYMJjULZDstQzrQnIDuYNTq6OoJZRKSeVPSYT5'
Access_token ='1192814806681735176-yoniPsr4XMEOdtsphlq9NPKWVfte4K'
Access_token_Secret ='DF12pXdBaKTuvgWDovnApk9EEAh1ibmOvvUaExH40qN6D'

tweets_file = open('python.json', 'a')

class Listener(StreamListener):
    def on_data(self, data):
           print(data)

auth = tweepy.OAuthHandler(Consumer_Key, Consumer_Secret)
auth.set_access_token(Access_token, Access_token_Secret)    
StreamListener = Listener()
Streamer = Stream(auth,Listener())
Streamer.filter(track=['Texas'])
print( "100 record inserted: ", Texas)
# Out:
# {"created_at":"Fri Nov 22 16:52:43 +0000 2019","id":1197920856149655552,"id_str":"1197920856149655552","text":"RT @DianeLong22: \"The Left are Authoritarian Criminals Who Love Communist China!\u201d - Alex Jones and His Battle Tank Return, Protest Apple in\u2026","source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":466789572,"id_str":"466789572","name":"Anne E. Patriot\u2b50\ufe0f\u2b50\ufe0f\u2b50\ufe0f","screen_name":"MissILmom","location":null,"url":"http:\/\/Tunnel2Towers.org","description":"Ret FFwife,USAF,USMC,DAR,Texan #KAG #OneNationUnderGod #ProLife #2A FB:@GenFlynn @DineshDSouza @AntonioSabatoJr @RudyGiuliani @staceydash @ScottBaio @Lrihendry","translator_type":"none","protected":false,"verified":false,"followers_count":77546,"friends_coun
# ...

# %% [markdown]
# # question 1.4(b)

# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import time

Consumer_Key = 'oQ4wA3nWX6SrXaK5HdmQBOdw8'
Consumer_Secret = 'XH2usYlx0Kp3gYMJjULZDstQzrQnIDuYNTq6OoJZRKSeVPSYT5'
Access_token ='1192814806681735176-yoniPsr4XMEOdtsphlq9NPKWVfte4K'
Access_token_Secret ='DF12pXdBaKTuvgWDovnApk9EEAh1ibmOvvUaExH40qN6D'

tweets_file = open('python.json', 'a')

class Listener(StreamListener):
    def on_data(self, data):
           print(data)

auth = tweepy.OAuthHandler(Consumer_Key, Consumer_Secret)
auth.set_access_token(Access_token, Access_token_Secret)    
StreamListener = Listener()
Streamer = Stream(auth,Listener())
Streamer.filter(track=["#UNT"])
print("100 record inserted: ", UNT)

# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import datetime
Consumer_Key = 'oQ4wA3nWX6SrXaK5HdmQBOdw8'
Consumer_Secret = 'XH2usYlx0Kp3gYMJjULZDstQzrQnIDuYNTq6OoJZRKSeVPSYT5'
Access_token ='1192814806681735176-yoniPsr4XMEOdtsphlq9NPKWVfte4K'
Access_token_Secret ='DF12pXdBaKTuvgWDovnApk9EEAh1ibmOvvUaExH40qN6D'

# saving data into json format
tweets_file = open('python.json', 'a')

class Listener(StreamListener):
        def on_data(self, data):
              print(data)    
since_startdate ='2019-7-20'
until_enduntil ='2019-7-25'
auth= tweepy.OAuthHandler(Consumer_Key, Consumer_Secret)
auth.set_access_token(Access_token, Access_token_Secret)    
StreamListener = Listener()
Streamer = Stream(auth,Listener())
Streamer.filter(track=["#UNT"] datetime[since_startdate='2019-7-20' until_enduntil ='2019-7-25'] )
print( "100 record inserted: ", UNT)

# %% [markdown]
# # question 1.4(c)

# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json

Consumer_Key = 'oQ4wA3nWX6SrXaK5HdmQBOdw8'
Consumer_Secret = 'XH2usYlx0Kp3gYMJjULZDstQzrQnIDuYNTq6OoJZRKSeVPSYT5'
Access_token ='1192814806681735176-yoniPsr4XMEOdtsphlq9NPKWVfte4K'
Access_token_Secret ='DF12pXdBaKTuvgWDovnApk9EEAh1ibmOvvUaExH40qN6D'

# saving data into json format
tweets_file = open('python.json', 'a')

class Listener(StreamListener):
        def on_data(self, data):
              print(data)  

auth= tweepy.OAuthHandler(Consumer_Key, Consumer_Secret)
auth.set_access_token(Access_token, Access_token_Secret)    
StreamListener = Listener()
Streamer = Stream(auth, Listener())
Streamer.filter(track=["location= South Bend:[-86.33,41.63,-86.20,41.74]"])
print( "100 record inserted: ", location)
